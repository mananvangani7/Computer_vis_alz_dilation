# %%
import zipfile
with zipfile.ZipFile("mri2.zip", 'r') as zip_ref:
   zip_ref.extractall()

# %%
import cv2
import os
import numpy as np
import pandas as pd
from math import exp, sqrt
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.image as mpimg
from sklearn.utils import shuffle
import keras
import tensorflow as tf
import tensorflow.keras.backend as K
from keras import Input
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import  BatchNormalization, Concatenate, Add, DepthwiseConv2D, GlobalAveragePooling2D, SeparableConv2D
from tensorflow.keras.optimizers import SGD,RMSprop,Adam,Adagrad
from keras.layers import Conv2D, MaxPooling2D
# Out:
# 2024-09-10 04:14:19.656042: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9373] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-10 04:14:19.656103: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-10 04:14:19.657570: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1534] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-10 04:14:19.665934: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data_path = 'MRI2'
data_dir_list = os.listdir(data_path)
img_data_list = []
labels = []

for dataset in data_dir_list:
    img_list = os.listdir(os.path.join(data_path, dataset))
    print('Loaded the images of dataset-{}\n'.format(dataset))
    for img in img_list:
        if img.lower().endswith(('.png', '.jpg', '.jpeg')):
            input_img = cv2.imread(os.path.join(data_path, dataset, img))
            if input_img is not None:
                img = cv2.resize(input_img, (224, 224))
                labels.append(dataset)
                img_data_list.append(img)

label = np.array(labels)
img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data = img_data / 255.0
print(img_data.shape)
# Out:
# Loaded the images of dataset-CN
#
# Loaded the images of dataset-SMC
#
# Loaded the images of dataset-LMCI
#
# Loaded the images of dataset-MCI
#
# Loaded the images of dataset-EMCI
#
# Loaded the images of dataset-AD
#
# (9752, 224, 224, 3)

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

class_names = ['CN', 'SMC', 'LMCI', 'MCI', 'EMCI', 'AD']
class_mapping = {name: idx for idx, name in enumerate(class_names)}
integer_labels = [class_mapping[label] for label in labels]
num_classes = len(class_names)
Y = to_categorical(integer_labels, num_classes)
x, y = shuffle(img_data, Y, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (7801, 224, 224, 3)
# X_test shape: (1951, 224, 224, 3)
# y_train shape: (7801, 6)
# y_test shape: (1951, 6)

# %%
X_train = X_train.reshape(-1, 224, 224, 3)
X_test = X_test.reshape(-1, 224, 224, 3)

# %%
import keras
from keras.models import Model
from tensorflow.keras import regularizers
from keras.layers import Input, Conv2D, Add, Multiply, Concatenate, AveragePooling2D, Flatten, DepthwiseConv2D, BatchNormalization
from keras.layers import SeparableConv2D, MaxPooling2D, Dense, GlobalAveragePooling2D, Activation
from tensorflow.keras.applications import ResNet50, VGG16, MobileNet

base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers[:12]:
    layer.trainable = False
x = base_model.output
x1 = Conv2D(64, (3, 3),  dilation_rate = 1, padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(x)
x1 = BatchNormalization()(x1)
x2 = Conv2D(64, (3, 3),  dilation_rate = 3, padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(x)
x2 = BatchNormalization()(x2)
x3 = Conv2D(64, (3, 3),  dilation_rate = 5, padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(x)
x3 = BatchNormalization()(x3)

A1 = Add()([x1, x2])
M1 = Multiply()([x2, x3])

x4 = Conv2D(64, (3, 3), padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(A1)
x4 = BatchNormalization()(x4)
g1 = GlobalAveragePooling2D()(x4)
d1 = Dense(1, activation = 'sigmoid')(g1)
M3 = Multiply()([d1, x1])

x5 = Activation('softmax')(M1)
M2 = Multiply()([x3, x5])

C1 = Concatenate()([M2, M3])
x5 = Conv2D(64, (3, 3), padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(C1)
C2 = Concatenate()([x5, x])

x = GlobalAveragePooling2D()(C2)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
output = Dense(6, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=output)
model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['acc'])
#model.summary()

# %%
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(
                              patience=30,
                              min_delta=0.001,
                              monitor="val_acc",
                              restore_best_weights=True
                              )
# Define the model checkpoint callback to save the best weights
#checkpoint = ModelCheckpoint('/workspace/notebooks/Mri - Alzimers/Data /Check/'+'-{epoch:02d}.h5', monitor='val_acc', save_best_only=True)


history = model.fit( X_train, y_train, batch_size = 32, epochs = 200,
                    validation_data = (X_test , y_test), callbacks=[early_stopping], verbose =1)
# Out:
# Epoch 1/200
# 2024-09-10 04:16:47.791863: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:467] Loaded cuDNN version 90100
# 2024-09-10 04:16:49.399263: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f85f57e0690 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-09-10 04:16:49.399308: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB MIG 3g.20gb, Compute Capability 8.0
# 2024-09-10 04:16:49.405488: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725941809.499801    1573 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 244/244 [==============================] - 34s 77ms/step - loss: 17.0175 - acc: 0.4665 - val_loss: 11.2216 - val_acc: 0.4546
# Epoch 2/200
# 244/244 [==============================] - 12s 51ms/step - loss: 10.4345 - acc: 0.5934 - val_loss: 10.4734 - val_acc: 0.5500
# Epoch 3/200
# 244/244 [==============================] - 13s 52ms/step - loss: 10.1504 - acc: 0.7250 - val_loss: 12.5150 - val_acc: 0.3885
# Epoch 4/200
# 244/244 [==============================] - 12s 47ms/step - loss: 9.9334 - acc: 0.8095 - val_loss: 10.4164 - val_acc: 0.6648
# Epoch 5/200
# 244/244 [==============================] - 12s 48ms/step - loss: 9.7890 - acc: 0.8646 - val_loss: 10.9949 - val_acc: 0.6330
# Epoch 6/200
# 244/244 [==============================] - 11s 45ms/step - loss: 9.7130 - acc: 0.8924 - val_loss: 10.4742 - val_acc: 0.6571
# Epoch 7/200
# 244/244 [==============================] - 12s 47ms/step - loss: 9.6665 - acc: 0.9126 - val_loss: 10.2799 - val_acc: 0.7668
# Epoch 8/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.6300 - acc: 0.9245 - val_loss: 10.8380 - val_acc: 0.6530
# Epoch 9/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.6009 - acc: 0.9328 - val_loss: 10.6909 - val_acc: 0.6607
# Epoch 10/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.5818 - acc: 0.9412 - val_loss: 11.8621 - val_acc: 0.5633
# Epoch 11/200
# 244/244 [==============================] - 12s 48ms/step - loss: 9.5566 - acc: 0.9467 - val_loss: 11.7408 - val_acc: 0.5859
# Epoch 12/200
# 244/244 [==============================] - 11s 46ms/step - loss: 9.5505 - acc: 0.9512 - val_loss: 11.2463 - val_acc: 0.6238
# Epoch 13/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.5450 - acc: 0.9562 - val_loss: 10.4296 - val_acc: 0.7406
# Epoch 14/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.5305 - acc: 0.9585 - val_loss: 10.7984 - val_acc: 0.7422
# Epoch 15/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.5301 - acc: 0.9614 - val_loss: 11.0513 - val_acc: 0.7078
# Epoch 16/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.5179 - acc: 0.9635 - val_loss: 10.2670 - val_acc: 0.7965
# Epoch 17/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.5181 - acc: 0.9673 - val_loss: 11.0335 - val_acc: 0.6725
# Epoch 18/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.5084 - acc: 0.9672 - val_loss: 10.3511 - val_acc: 0.7873
# Epoch 19/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4889 - acc: 0.9732 - val_loss: 11.6659 - val_acc: 0.6566
# Epoch 20/200
# 244/244 [==============================] - 11s 44ms/step - loss: 9.5064 - acc: 0.9685 - val_loss: 10.3640 - val_acc: 0.7806
# Epoch 21/200
# 244/244 [==============================] - 11s 45ms/step - loss: 9.5020 - acc: 0.9694 - val_loss: 10.6677 - val_acc: 0.7637
# Epoch 22/200
# 244/244 [==============================] - 11s 44ms/step - loss: 9.4919 - acc: 0.9733 - val_loss: 12.2905 - val_acc: 0.5787
# Epoch 23/200
# 244/244 [==============================] - 11s 44ms/step - loss: 9.4806 - acc: 0.9745 - val_loss: 12.4981 - val_acc: 0.6591
# Epoch 24/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4927 - acc: 0.9740 - val_loss: 12.4253 - val_acc: 0.6115
# Epoch 25/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4928 - acc: 0.9741 - val_loss: 10.8207 - val_acc: 0.7729
# Epoch 26/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4796 - acc: 0.9782 - val_loss: 10.5848 - val_acc: 0.7806
# Epoch 27/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4834 - acc: 0.9772 - val_loss: 10.7737 - val_acc: 0.7514
# Epoch 28/200
# 244/244 [==============================] - 11s 43ms/step - loss: 9.4848 - acc: 0.9765 - val_loss: 10.5468 - val_acc: 0.7996
# Epoch 29/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4742 - acc: 0.9788 - val_loss: 10.7956 - val_acc: 0.7299
# Epoch 30/200
# 244/244 [==============================] - 11s 45ms/step - loss: 9.4629 - acc: 0.9828 - val_loss: 10.8101 - val_acc: 0.7678
# Epoch 31/200
# 244/244 [==============================] - 11s 46ms/step - loss: 9.4675 - acc: 0.9818 - val_loss: 10.8292 - val_acc: 0.7601
# Epoch 32/200
# 244/244 [==============================] - 11s 44ms/step - loss: 9.4825 - acc: 0.9786 - val_loss: 10.8152 - val_acc: 0.7442
# Epoch 33/200
# 244/244 [==============================] - 11s 43ms/step - loss: 9.4634 - acc: 0.9833 - val_loss: 11.6265 - val_acc: 0.7155
# Epoch 34/200
# 244/244 [==============================] - 11s 43ms/step - loss: 9.4792 - acc: 0.9800 - val_loss: 10.8859 - val_acc: 0.7381
# Epoch 35/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4752 - acc: 0.9819 - val_loss: 11.0755 - val_acc: 0.7473
# Epoch 36/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4660 - acc: 0.9831 - val_loss: 11.0827 - val_acc: 0.7478
# Epoch 37/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4628 - acc: 0.9830 - val_loss: 10.6896 - val_acc: 0.7873
# Epoch 38/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4599 - acc: 0.9824 - val_loss: 10.6482 - val_acc: 0.7996
# Epoch 39/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4529 - acc: 0.9855 - val_loss: 10.7043 - val_acc: 0.7775
# Epoch 40/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4532 - acc: 0.9846 - val_loss: 11.0139 - val_acc: 0.7637
# Epoch 41/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4531 - acc: 0.9849 - val_loss: 10.9569 - val_acc: 0.7601
# Epoch 42/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4497 - acc: 0.9871 - val_loss: 10.5508 - val_acc: 0.8145
# Epoch 43/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4607 - acc: 0.9847 - val_loss: 11.2588 - val_acc: 0.6950
# Epoch 44/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4467 - acc: 0.9853 - val_loss: 10.9245 - val_acc: 0.7852
# Epoch 45/200
# 244/244 [==============================] - 11s 44ms/step - loss: 9.4522 - acc: 0.9868 - val_loss: 10.4706 - val_acc: 0.8078
# Epoch 46/200
# 244/244 [==============================] - 11s 45ms/step - loss: 9.4540 - acc: 0.9859 - val_loss: 10.4363 - val_acc: 0.7986
# Epoch 47/200
# 244/244 [==============================] - 11s 44ms/step - loss: 9.4489 - acc: 0.9873 - val_loss: 10.8347 - val_acc: 0.7750
# Epoch 48/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4555 - acc: 0.9873 - val_loss: 10.5739 - val_acc: 0.7899
# Epoch 49/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4502 - acc: 0.9869 - val_loss: 11.9677 - val_acc: 0.7386
# Epoch 50/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4540 - acc: 0.9872 - val_loss: 12.1906 - val_acc: 0.6474
# Epoch 51/200
# 244/244 [==============================] - 11s 44ms/step - loss: 9.4398 - acc: 0.9915 - val_loss: 10.5392 - val_acc: 0.8027
# Epoch 52/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4516 - acc: 0.9855 - val_loss: 12.5706 - val_acc: 0.6966
# Epoch 53/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4562 - acc: 0.9850 - val_loss: 10.9751 - val_acc: 0.7581
# Epoch 54/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4457 - acc: 0.9886 - val_loss: 12.0580 - val_acc: 0.7222
# Epoch 55/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4533 - acc: 0.9877 - val_loss: 10.4024 - val_acc: 0.8196
# Epoch 56/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4441 - acc: 0.9894 - val_loss: 11.2440 - val_acc: 0.7591
# Epoch 57/200
# 244/244 [==============================] - 11s 43ms/step - loss: 9.4438 - acc: 0.9891 - val_loss: 10.9878 - val_acc: 0.7981
# Epoch 58/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4476 - acc: 0.9871 - val_loss: 10.3401 - val_acc: 0.8237
# Epoch 59/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4462 - acc: 0.9897 - val_loss: 10.7583 - val_acc: 0.7360
# Epoch 60/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4431 - acc: 0.9906 - val_loss: 11.4582 - val_acc: 0.7565
# Epoch 61/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4422 - acc: 0.9883 - val_loss: 10.9958 - val_acc: 0.7822
# Epoch 62/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4425 - acc: 0.9906 - val_loss: 11.0906 - val_acc: 0.7668
# Epoch 63/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4429 - acc: 0.9887 - val_loss: 10.5089 - val_acc: 0.8191
# Epoch 64/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4389 - acc: 0.9897 - val_loss: 11.6346 - val_acc: 0.7555
# Epoch 65/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4374 - acc: 0.9905 - val_loss: 10.9599 - val_acc: 0.7740
# Epoch 66/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4470 - acc: 0.9894 - val_loss: 10.3357 - val_acc: 0.8365
# Epoch 67/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4344 - acc: 0.9922 - val_loss: 10.5485 - val_acc: 0.8211
# Epoch 68/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4405 - acc: 0.9909 - val_loss: 10.8421 - val_acc: 0.7950
# Epoch 69/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4425 - acc: 0.9900 - val_loss: 11.9608 - val_acc: 0.7324
# Epoch 70/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4421 - acc: 0.9886 - val_loss: 10.4889 - val_acc: 0.7822
# Epoch 71/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4423 - acc: 0.9906 - val_loss: 11.0904 - val_acc: 0.7919
# Epoch 72/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4420 - acc: 0.9903 - val_loss: 10.9244 - val_acc: 0.7950
# Epoch 73/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4326 - acc: 0.9913 - val_loss: 10.8443 - val_acc: 0.8032
# Epoch 74/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4369 - acc: 0.9897 - val_loss: 11.5483 - val_acc: 0.7483
# Epoch 75/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4439 - acc: 0.9929 - val_loss: 10.8664 - val_acc: 0.7806
# Epoch 76/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4344 - acc: 0.9926 - val_loss: 10.4537 - val_acc: 0.8283
# Epoch 77/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4340 - acc: 0.9922 - val_loss: 11.5848 - val_acc: 0.7791
# Epoch 78/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4443 - acc: 0.9912 - val_loss: 10.5240 - val_acc: 0.8355
# Epoch 79/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4340 - acc: 0.9909 - val_loss: 10.5113 - val_acc: 0.8344
# Epoch 80/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4378 - acc: 0.9904 - val_loss: 10.7533 - val_acc: 0.8073
# Epoch 81/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4379 - acc: 0.9929 - val_loss: 11.2760 - val_acc: 0.7817
# Epoch 82/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4318 - acc: 0.9928 - val_loss: 10.7656 - val_acc: 0.8211
# Epoch 83/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4395 - acc: 0.9918 - val_loss: 10.7048 - val_acc: 0.8001
# Epoch 84/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4310 - acc: 0.9923 - val_loss: 11.0202 - val_acc: 0.8221
# Epoch 85/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4367 - acc: 0.9936 - val_loss: 10.8587 - val_acc: 0.8057
# Epoch 86/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4317 - acc: 0.9926 - val_loss: 11.0708 - val_acc: 0.7893
# Epoch 87/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4388 - acc: 0.9917 - val_loss: 10.5000 - val_acc: 0.8063
# Epoch 88/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4277 - acc: 0.9922 - val_loss: 11.4294 - val_acc: 0.7883
# Epoch 89/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4347 - acc: 0.9927 - val_loss: 11.8733 - val_acc: 0.7488
# Epoch 90/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4276 - acc: 0.9935 - val_loss: 10.7470 - val_acc: 0.8186
# Epoch 91/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4355 - acc: 0.9913 - val_loss: 11.6262 - val_acc: 0.7683
# Epoch 92/200
# 244/244 [==============================] - 11s 43ms/step - loss: 9.4268 - acc: 0.9932 - val_loss: 10.8166 - val_acc: 0.8247
# Epoch 93/200
# 244/244 [==============================] - 10s 43ms/step - loss: 9.4328 - acc: 0.9918 - val_loss: 10.8528 - val_acc: 0.8139
# Epoch 94/200
# 244/244 [==============================] - 10s 42ms/step - loss: 9.4359 - acc: 0.9933 - val_loss: 10.6218 - val_acc: 0.8278
# Epoch 95/200
# 244/244 [==============================] - 11s 44ms/step - loss: 9.4242 - acc: 0.9949 - val_loss: 10.9869 - val_acc: 0.7688
# Epoch 96/200
# 244/244 [==============================] - 11s 43ms/step - loss: 9.4291 - acc: 0.9928 - val_loss: 10.8807 - val_acc: 0.7827

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# Predicting the Test set results
pred = model.predict(X_test)
print("Y_pred:", pred)
print("*****************")
y_pred = np.argmax(pred, axis = 1)
y_true = np.argmax(y_test, axis = 1)
# Out:
# 61/61 [==============================] - 1s 15ms/step - loss: 10.3357 - acc: 0.8365
# Test Loss: 10.335686683654785
# Test Accuracy: 0.8364940881729126
# 61/61 [==============================] - 3s 14ms/step
# Y_pred: [[1.2514050e-07 6.0142277e-08 1.6055807e-08 9.5852934e-09 9.9999976e-01
#   7.7360980e-09]
#  [8.0206003e-03 3.2706431e-04 8.2548815e-01 4.0299678e-04 1.6419031e-01
#   1.5709151e-03]
#  [1.4062254e-13 1.0000000e+00 8.5210682e-19 1.8308785e-18 1.7643701e-17
#   3.3565184e-28]
#  ...
#  [9.7681957e-01 8.9033268e-04 5.7445618e-04 4.2234939e-03 1.6755706e-02
#   7.3644955e-04]
#  [1.5160125e-09 2.2087713e-19 1.4234156e-12 5.9644943e-14 8.5443024e-13
#   1.0000000e+00]
#  [1.6260633e-01 7.5467173e-03 3.1132883e-01 2.2297329e-03 4.8577678e-01
#   3.0511623e-02]]
# *****************

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)
target_names = ["CN",

"SMC",

"LMCI",

"MCI",

"EMCI",

"AD"]
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set(font_scale=1.25)
p = sns.heatmap(pd.DataFrame(cm), annot=True,xticklabels=target_names, yticklabels=target_names, cmap="YlGnBu" ,fmt='g')
plt.title('RMSprop', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.049999999999999, 'Predicted label')

# %%
import keras
from keras.models import Model
from tensorflow.keras import regularizers
from keras.layers import Input, Conv2D, Add, Multiply, Concatenate, AveragePooling2D, Flatten, DepthwiseConv2D, BatchNormalization
from keras.layers import SeparableConv2D, MaxPooling2D, Dense, GlobalAveragePooling2D, Activation
from tensorflow.keras.applications import ResNet50, VGG16, MobileNet

base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers[:12]:
    layer.trainable = False
x = base_model.output
x1 = Conv2D(64, (3, 3),  dilation_rate = 1, padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(x)
x1 = BatchNormalization()(x1)
x2 = Conv2D(64, (3, 3),  dilation_rate = 3, padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(x)
x2 = BatchNormalization()(x2)
x3 = Conv2D(64, (3, 3),  dilation_rate = 5, padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(x)
x3 = BatchNormalization()(x3)

A1 = Add()([x1, x2])
M1 = Multiply()([x2, x3])

x4 = Conv2D(64, (3, 3), padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(A1)
x4 = BatchNormalization()(x4)
g1 = GlobalAveragePooling2D()(x4)
d1 = Dense(1, activation = 'sigmoid')(g1)
M3 = Multiply()([d1, x1])

x5 = Activation('softmax')(M1)
M2 = Multiply()([x3, x5])

C1 = Concatenate()([M2, M3])
x5 = Conv2D(64, (3, 3), padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(C1)
C2 = Concatenate()([x5, x])

x = GlobalAveragePooling2D()(C2)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
output = Dense(6, activation='softmax')(x)
model1 = Model(inputs=base_model.input, outputs=output)
model1.compile(optimizer='Adagrad', loss='categorical_crossentropy', metrics=['acc'])
#model.summary()

# %%
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(
                              patience=30,
                              min_delta=0.001,
                              monitor="val_acc",
                              restore_best_weights=True
                              )
# Define the model checkpoint callback to save the best weights
#checkpoint = ModelCheckpoint('/workspace/notebooks/Mri - Alzimers/Data /Check/'+'-{epoch:02d}.h5', monitor='val_acc', save_best_only=True)


history = model1.fit( X_train, y_train, batch_size = 32, epochs = 200,
                    validation_data = (X_test , y_test), callbacks=[early_stopping], verbose =1)
# Out:
# Epoch 1/200
# 244/244 [==============================] - 25s 51ms/step - loss: 194.7501 - acc: 0.3943 - val_loss: 137.6062 - val_acc: 0.4700
# Epoch 2/200
# 244/244 [==============================] - 10s 42ms/step - loss: 97.0230 - acc: 0.5012 - val_loss: 63.0202 - val_acc: 0.5110
# Epoch 3/200
# 244/244 [==============================] - 10s 43ms/step - loss: 41.1624 - acc: 0.5704 - val_loss: 24.4426 - val_acc: 0.5792
# Epoch 4/200
# 244/244 [==============================] - 10s 43ms/step - loss: 16.9505 - acc: 0.6304 - val_loss: 13.2063 - val_acc: 0.6084
# Epoch 5/200
# 244/244 [==============================] - 10s 43ms/step - loss: 11.3235 - acc: 0.6944 - val_loss: 9.8617 - val_acc: 0.6330
# Epoch 6/200
# 244/244 [==============================] - 11s 43ms/step - loss: 8.2443 - acc: 0.7668 - val_loss: 7.1987 - val_acc: 0.6453
# Epoch 7/200
# 244/244 [==============================] - 10s 42ms/step - loss: 5.8240 - acc: 0.8239 - val_loss: 5.0948 - val_acc: 0.6827
# Epoch 8/200
# 244/244 [==============================] - 10s 42ms/step - loss: 3.9460 - acc: 0.8721 - val_loss: 3.5233 - val_acc: 0.7160
# Epoch 9/200
# 244/244 [==============================] - 11s 43ms/step - loss: 2.5573 - acc: 0.9073 - val_loss: 2.3972 - val_acc: 0.7248
# Epoch 10/200
# 244/244 [==============================] - 10s 43ms/step - loss: 1.5755 - acc: 0.9355 - val_loss: 1.6538 - val_acc: 0.7335
# Epoch 11/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.9581 - acc: 0.9576 - val_loss: 1.2338 - val_acc: 0.7447
# Epoch 12/200
# 244/244 [==============================] - 11s 44ms/step - loss: 0.6249 - acc: 0.9700 - val_loss: 0.9964 - val_acc: 0.7596
# Epoch 13/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.4100 - acc: 0.9830 - val_loss: 0.8691 - val_acc: 0.7560
# Epoch 14/200
# 244/244 [==============================] - 11s 44ms/step - loss: 0.2863 - acc: 0.9904 - val_loss: 0.7816 - val_acc: 0.7714
# Epoch 15/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.2352 - acc: 0.9935 - val_loss: 0.7800 - val_acc: 0.7632
# Epoch 16/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.2144 - acc: 0.9951 - val_loss: 0.7528 - val_acc: 0.7781
# Epoch 17/200
# 244/244 [==============================] - 11s 44ms/step - loss: 0.1968 - acc: 0.9985 - val_loss: 0.7547 - val_acc: 0.7775
# Epoch 18/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.1839 - acc: 0.9976 - val_loss: 0.7404 - val_acc: 0.7909
# Epoch 19/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.1726 - acc: 0.9987 - val_loss: 0.7424 - val_acc: 0.7868
# Epoch 20/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.1624 - acc: 0.9997 - val_loss: 0.7318 - val_acc: 0.7929
# Epoch 21/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.1564 - acc: 0.9996 - val_loss: 0.7255 - val_acc: 0.7940
# Epoch 22/200
# 244/244 [==============================] - 11s 44ms/step - loss: 0.1525 - acc: 0.9987 - val_loss: 0.7157 - val_acc: 0.7960
# Epoch 23/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.1456 - acc: 0.9999 - val_loss: 0.7175 - val_acc: 0.8001
# Epoch 24/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.1389 - acc: 0.9999 - val_loss: 0.7145 - val_acc: 0.8032
# Epoch 25/200
# 244/244 [==============================] - 11s 43ms/step - loss: 0.1356 - acc: 0.9996 - val_loss: 0.7100 - val_acc: 0.8022
# Epoch 26/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.1313 - acc: 0.9996 - val_loss: 0.7205 - val_acc: 0.7965
# Epoch 27/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.1280 - acc: 0.9999 - val_loss: 0.7126 - val_acc: 0.8016
# Epoch 28/200
# 244/244 [==============================] - 11s 46ms/step - loss: 0.1249 - acc: 0.9997 - val_loss: 0.7069 - val_acc: 0.8006
# Epoch 29/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.1208 - acc: 0.9996 - val_loss: 0.7082 - val_acc: 0.8011
# Epoch 30/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.1184 - acc: 1.0000 - val_loss: 0.7074 - val_acc: 0.8037
# Epoch 31/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.1160 - acc: 1.0000 - val_loss: 0.7093 - val_acc: 0.8052
# Epoch 32/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.1127 - acc: 0.9999 - val_loss: 0.7035 - val_acc: 0.8037
# Epoch 33/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.1114 - acc: 1.0000 - val_loss: 0.7041 - val_acc: 0.8073
# Epoch 34/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.1093 - acc: 0.9999 - val_loss: 0.7035 - val_acc: 0.8027
# Epoch 35/200
# 244/244 [==============================] - 11s 43ms/step - loss: 0.1070 - acc: 1.0000 - val_loss: 0.7065 - val_acc: 0.8052
# Epoch 36/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.1062 - acc: 1.0000 - val_loss: 0.6990 - val_acc: 0.8052
# Epoch 37/200
# 244/244 [==============================] - 11s 43ms/step - loss: 0.1037 - acc: 1.0000 - val_loss: 0.7005 - val_acc: 0.8083
# Epoch 38/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.1020 - acc: 0.9997 - val_loss: 0.7004 - val_acc: 0.8078
# Epoch 39/200
# 244/244 [==============================] - 11s 46ms/step - loss: 0.0999 - acc: 1.0000 - val_loss: 0.7058 - val_acc: 0.8063
# Epoch 40/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0991 - acc: 1.0000 - val_loss: 0.6997 - val_acc: 0.8093
# Epoch 41/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0976 - acc: 0.9999 - val_loss: 0.6961 - val_acc: 0.8139
# Epoch 42/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0964 - acc: 1.0000 - val_loss: 0.7006 - val_acc: 0.8098
# Epoch 43/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0951 - acc: 1.0000 - val_loss: 0.7036 - val_acc: 0.8109
# Epoch 44/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0939 - acc: 1.0000 - val_loss: 0.7004 - val_acc: 0.8068
# Epoch 45/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0923 - acc: 1.0000 - val_loss: 0.6969 - val_acc: 0.8098
# Epoch 46/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0912 - acc: 1.0000 - val_loss: 0.6965 - val_acc: 0.8129
# Epoch 47/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0903 - acc: 1.0000 - val_loss: 0.6988 - val_acc: 0.8088
# Epoch 48/200
# 244/244 [==============================] - 11s 43ms/step - loss: 0.0890 - acc: 1.0000 - val_loss: 0.7021 - val_acc: 0.8104
# Epoch 49/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0882 - acc: 1.0000 - val_loss: 0.7004 - val_acc: 0.8104
# Epoch 50/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0873 - acc: 1.0000 - val_loss: 0.6998 - val_acc: 0.8129
# Epoch 51/200
# 244/244 [==============================] - 11s 43ms/step - loss: 0.0864 - acc: 1.0000 - val_loss: 0.6977 - val_acc: 0.8160
# Epoch 52/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.0851 - acc: 1.0000 - val_loss: 0.7041 - val_acc: 0.8114
# Epoch 53/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0842 - acc: 1.0000 - val_loss: 0.7057 - val_acc: 0.8139
# Epoch 54/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0839 - acc: 0.9999 - val_loss: 0.7048 - val_acc: 0.8124
# Epoch 55/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0832 - acc: 0.9999 - val_loss: 0.6972 - val_acc: 0.8160
# Epoch 56/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0817 - acc: 1.0000 - val_loss: 0.6991 - val_acc: 0.8129
# Epoch 57/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0811 - acc: 1.0000 - val_loss: 0.7000 - val_acc: 0.8134
# Epoch 58/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0800 - acc: 1.0000 - val_loss: 0.7013 - val_acc: 0.8124
# Epoch 59/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0796 - acc: 1.0000 - val_loss: 0.6974 - val_acc: 0.8150
# Epoch 60/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0789 - acc: 1.0000 - val_loss: 0.6983 - val_acc: 0.8165
# Epoch 61/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0785 - acc: 1.0000 - val_loss: 0.6972 - val_acc: 0.8124
# Epoch 62/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0771 - acc: 1.0000 - val_loss: 0.7000 - val_acc: 0.8134
# Epoch 63/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0767 - acc: 1.0000 - val_loss: 0.7009 - val_acc: 0.8139
# Epoch 64/200
# 244/244 [==============================] - 11s 43ms/step - loss: 0.0762 - acc: 1.0000 - val_loss: 0.6955 - val_acc: 0.8155
# Epoch 65/200
# 244/244 [==============================] - 11s 43ms/step - loss: 0.0758 - acc: 1.0000 - val_loss: 0.6922 - val_acc: 0.8191
# Epoch 66/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0748 - acc: 1.0000 - val_loss: 0.6956 - val_acc: 0.8196
# Epoch 67/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0745 - acc: 1.0000 - val_loss: 0.6951 - val_acc: 0.8191
# Epoch 68/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0740 - acc: 1.0000 - val_loss: 0.6954 - val_acc: 0.8165
# Epoch 69/200
# 244/244 [==============================] - 11s 44ms/step - loss: 0.0733 - acc: 1.0000 - val_loss: 0.6988 - val_acc: 0.8165
# Epoch 70/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0727 - acc: 0.9999 - val_loss: 0.6994 - val_acc: 0.8186
# Epoch 71/200
# 244/244 [==============================] - 11s 44ms/step - loss: 0.0725 - acc: 1.0000 - val_loss: 0.6940 - val_acc: 0.8180
# Epoch 72/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0719 - acc: 0.9999 - val_loss: 0.6996 - val_acc: 0.8180
# Epoch 73/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0712 - acc: 1.0000 - val_loss: 0.6953 - val_acc: 0.8175
# Epoch 74/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0707 - acc: 0.9999 - val_loss: 0.6937 - val_acc: 0.8180
# Epoch 75/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0702 - acc: 1.0000 - val_loss: 0.6942 - val_acc: 0.8201
# Epoch 76/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0698 - acc: 1.0000 - val_loss: 0.6935 - val_acc: 0.8186
# Epoch 77/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0689 - acc: 1.0000 - val_loss: 0.6937 - val_acc: 0.8206
# Epoch 78/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0689 - acc: 1.0000 - val_loss: 0.6947 - val_acc: 0.8216
# Epoch 79/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0681 - acc: 1.0000 - val_loss: 0.6952 - val_acc: 0.8206
# Epoch 80/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0677 - acc: 1.0000 - val_loss: 0.6932 - val_acc: 0.8211
# Epoch 81/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0672 - acc: 1.0000 - val_loss: 0.6963 - val_acc: 0.8170
# Epoch 82/200
# 244/244 [==============================] - 11s 43ms/step - loss: 0.0668 - acc: 1.0000 - val_loss: 0.6949 - val_acc: 0.8196
# Epoch 83/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0664 - acc: 1.0000 - val_loss: 0.6959 - val_acc: 0.8191
# Epoch 84/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0661 - acc: 1.0000 - val_loss: 0.6970 - val_acc: 0.8196
# Epoch 85/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0656 - acc: 1.0000 - val_loss: 0.6922 - val_acc: 0.8175
# Epoch 86/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0654 - acc: 1.0000 - val_loss: 0.6971 - val_acc: 0.8216
# Epoch 87/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0649 - acc: 0.9999 - val_loss: 0.6927 - val_acc: 0.8191
# Epoch 88/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0644 - acc: 1.0000 - val_loss: 0.6953 - val_acc: 0.8180
# Epoch 89/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0641 - acc: 1.0000 - val_loss: 0.6944 - val_acc: 0.8201
# Epoch 90/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0635 - acc: 1.0000 - val_loss: 0.6984 - val_acc: 0.8180
# Epoch 91/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0638 - acc: 0.9999 - val_loss: 0.6972 - val_acc: 0.8180
# Epoch 92/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0630 - acc: 1.0000 - val_loss: 0.7012 - val_acc: 0.8191
# Epoch 93/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0626 - acc: 1.0000 - val_loss: 0.6996 - val_acc: 0.8196
# Epoch 94/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0622 - acc: 1.0000 - val_loss: 0.6997 - val_acc: 0.8175
# Epoch 95/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0617 - acc: 1.0000 - val_loss: 0.6983 - val_acc: 0.8186
# Epoch 96/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0615 - acc: 1.0000 - val_loss: 0.6972 - val_acc: 0.8175
# Epoch 97/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0611 - acc: 1.0000 - val_loss: 0.7000 - val_acc: 0.8191
# Epoch 98/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0609 - acc: 1.0000 - val_loss: 0.7000 - val_acc: 0.8160
# Epoch 99/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0605 - acc: 1.0000 - val_loss: 0.6952 - val_acc: 0.8196
# Epoch 100/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0604 - acc: 1.0000 - val_loss: 0.6963 - val_acc: 0.8186
# Epoch 101/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0598 - acc: 1.0000 - val_loss: 0.6971 - val_acc: 0.8196
# Epoch 102/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0598 - acc: 1.0000 - val_loss: 0.6987 - val_acc: 0.8186
# Epoch 103/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0595 - acc: 1.0000 - val_loss: 0.6963 - val_acc: 0.8165
# Epoch 104/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0590 - acc: 1.0000 - val_loss: 0.6957 - val_acc: 0.8186
# Epoch 105/200
# 244/244 [==============================] - 11s 43ms/step - loss: 0.0588 - acc: 1.0000 - val_loss: 0.6963 - val_acc: 0.8196
# Epoch 106/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0586 - acc: 1.0000 - val_loss: 0.6952 - val_acc: 0.8211
# Epoch 107/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0583 - acc: 1.0000 - val_loss: 0.6931 - val_acc: 0.8196
# Epoch 108/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0580 - acc: 1.0000 - val_loss: 0.6965 - val_acc: 0.8211

# %%
loss, accuracy = model1.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# Predicting the Test set results
pred = model1.predict(X_test)
print("Y_pred:", pred)
print("*****************")
y_pred1 = np.argmax(pred, axis = 1)
y_true1 = np.argmax(y_test, axis = 1)
# Out:
# 61/61 [==============================] - 1s 15ms/step - loss: 0.6947 - acc: 0.8216
# Test Loss: 0.6946994662284851
# Test Accuracy: 0.8216299414634705
# 61/61 [==============================] - 3s 14ms/step
# Y_pred: [[9.95199152e-05 1.89120474e-03 1.35256632e-04 4.54063138e-06
#   9.97827947e-01 4.15007926e-05]
#  [2.03947444e-03 3.52322892e-03 1.49476193e-02 1.92792777e-06
#   9.77029264e-01 2.45850882e-03]
#  [9.02170062e-01 8.07539448e-02 4.68849996e-03 1.22743575e-02
#   1.11381240e-04 1.78008077e-06]
#  ...
#  [7.49570489e-01 2.90649536e-04 2.33445302e-01 8.27213225e-05
#   1.65996626e-02 1.12325215e-05]
#  [2.02526309e-04 7.68537120e-06 2.78116728e-04 3.63402432e-05
#   6.55938420e-05 9.99409676e-01]
#  [1.71556300e-03 3.16831902e-05 3.32680494e-01 3.05939784e-06
#   6.65554225e-01 1.49767329e-05]]
# *****************

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true1, y_pred1)
target_names = ["CN",

"SMC",

"LMCI",

"MCI",

"EMCI",

"AD"]
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set(font_scale=1.25)
p = sns.heatmap(pd.DataFrame(cm), annot=True,xticklabels=target_names, yticklabels=target_names, cmap="YlGnBu" ,fmt='g')
plt.title('Adagrad', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.049999999999999, 'Predicted label')

# %%
import keras
from keras.models import Model
from tensorflow.keras import regularizers
from keras.layers import Input, Conv2D, Add, Multiply, Concatenate, AveragePooling2D, Flatten, DepthwiseConv2D, BatchNormalization
from keras.layers import SeparableConv2D, MaxPooling2D, Dense, GlobalAveragePooling2D, Activation
from tensorflow.keras.applications import ResNet50, VGG16, MobileNet

base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers[:12]:
    layer.trainable = False
x = base_model.output
x1 = Conv2D(64, (3, 3),  dilation_rate = 1, padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(x)
x1 = BatchNormalization()(x1)
x2 = Conv2D(64, (3, 3),  dilation_rate = 3, padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(x)
x2 = BatchNormalization()(x2)
x3 = Conv2D(64, (3, 3),  dilation_rate = 5, padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(x)
x3 = BatchNormalization()(x3)

A1 = Add()([x1, x2])
M1 = Multiply()([x2, x3])

x4 = Conv2D(64, (3, 3), padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(A1)
x4 = BatchNormalization()(x4)
g1 = GlobalAveragePooling2D()(x4)
d1 = Dense(1, activation = 'sigmoid')(g1)
M3 = Multiply()([d1, x1])

x5 = Activation('softmax')(M1)
M2 = Multiply()([x3, x5])

C1 = Concatenate()([M2, M3])
x5 = Conv2D(64, (3, 3), padding = 'same', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01), activation='relu')(C1)
C2 = Concatenate()([x5, x])

x = GlobalAveragePooling2D()(C2)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
output = Dense(6, activation='softmax')(x)
model2 = Model(inputs=base_model.input, outputs=output)
model2.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['acc'])
#model.summary()

# %%
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(
                              patience=30,
                              min_delta=0.001,
                              monitor="val_acc",
                              restore_best_weights=True
                              )
# Define the model checkpoint callback to save the best weights
#checkpoint = ModelCheckpoint('/workspace/notebooks/Mri - Alzimers/Data /Check/'+'-{epoch:02d}.h5', monitor='val_acc', save_best_only=True)


history = model2.fit( X_train, y_train, batch_size = 16, epochs = 200,
                    validation_data = (X_test , y_test), callbacks=[early_stopping], verbose =1)
# Out:
# Epoch 1/200
# 488/488 [==============================] - ETA: 0s - loss: 53.5478 - acc: 0.4825
# 2024-09-10 05:10:23.676861: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 488/488 [==============================] - 26s 32ms/step - loss: 53.5478 - acc: 0.4825 - val_loss: 3.3821 - val_acc: 0.5664
# Epoch 2/200
# 2024-09-10 05:10:25.013196: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.94GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 488/488 [==============================] - 13s 27ms/step - loss: 2.0290 - acc: 0.6290 - val_loss: 1.8667 - val_acc: 0.6479
# Epoch 3/200
# 488/488 [==============================] - 13s 27ms/step - loss: 1.5825 - acc: 0.7598 - val_loss: 2.1290 - val_acc: 0.5669
# Epoch 4/200
# 488/488 [==============================] - 13s 27ms/step - loss: 1.3462 - acc: 0.8540 - val_loss: 1.6547 - val_acc: 0.7345
# Epoch 5/200
# 488/488 [==============================] - 13s 26ms/step - loss: 1.2055 - acc: 0.9110 - val_loss: 1.7926 - val_acc: 0.7371
# Epoch 6/200
# 488/488 [==============================] - 13s 27ms/step - loss: 1.1369 - acc: 0.9296 - val_loss: 3.1483 - val_acc: 0.4987
# Epoch 7/200
# 488/488 [==============================] - 13s 27ms/step - loss: 1.0715 - acc: 0.9564 - val_loss: 1.8805 - val_acc: 0.7396
# Epoch 8/200
# 488/488 [==============================] - 13s 27ms/step - loss: 1.0598 - acc: 0.9577 - val_loss: 1.9960 - val_acc: 0.7360
# Epoch 9/200
# 488/488 [==============================] - 13s 27ms/step - loss: 1.0423 - acc: 0.9646 - val_loss: 1.6292 - val_acc: 0.8139
# Epoch 10/200
# 488/488 [==============================] - 13s 27ms/step - loss: 1.0288 - acc: 0.9689 - val_loss: 1.7584 - val_acc: 0.7945
# Epoch 11/200
# 488/488 [==============================] - 13s 27ms/step - loss: 1.0066 - acc: 0.9756 - val_loss: 1.6514 - val_acc: 0.8165
# Epoch 12/200
# 488/488 [==============================] - 14s 29ms/step - loss: 0.9920 - acc: 0.9827 - val_loss: 1.7673 - val_acc: 0.7975
# Epoch 13/200
# 488/488 [==============================] - 14s 28ms/step - loss: 1.0042 - acc: 0.9774 - val_loss: 1.7578 - val_acc: 0.8027
# Epoch 14/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9941 - acc: 0.9804 - val_loss: 1.5787 - val_acc: 0.8401
# Epoch 15/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9900 - acc: 0.9824 - val_loss: 1.7477 - val_acc: 0.8052
# Epoch 16/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9732 - acc: 0.9888 - val_loss: 1.8876 - val_acc: 0.7893
# Epoch 17/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9680 - acc: 0.9912 - val_loss: 1.6587 - val_acc: 0.8406
# Epoch 18/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9698 - acc: 0.9913 - val_loss: 1.6080 - val_acc: 0.8498
# Epoch 19/200
# 488/488 [==============================] - 13s 28ms/step - loss: 0.9757 - acc: 0.9887 - val_loss: 1.5508 - val_acc: 0.8601
# Epoch 20/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9724 - acc: 0.9899 - val_loss: 1.5306 - val_acc: 0.8483
# Epoch 21/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9757 - acc: 0.9883 - val_loss: 1.6262 - val_acc: 0.8416
# Epoch 22/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9715 - acc: 0.9903 - val_loss: 1.6269 - val_acc: 0.8262
# Epoch 23/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9706 - acc: 0.9895 - val_loss: 1.6961 - val_acc: 0.8175
# Epoch 24/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9604 - acc: 0.9926 - val_loss: 1.4129 - val_acc: 0.8795
# Epoch 25/200
# 488/488 [==============================] - 14s 28ms/step - loss: 0.9743 - acc: 0.9886 - val_loss: 1.6850 - val_acc: 0.8288
# Epoch 26/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9584 - acc: 0.9940 - val_loss: 1.5430 - val_acc: 0.8560
# Epoch 27/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9697 - acc: 0.9908 - val_loss: 1.4742 - val_acc: 0.8652
# Epoch 28/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9536 - acc: 0.9958 - val_loss: 1.5150 - val_acc: 0.8703
# Epoch 29/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9525 - acc: 0.9960 - val_loss: 1.4762 - val_acc: 0.8693
# Epoch 30/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9588 - acc: 0.9928 - val_loss: 1.6576 - val_acc: 0.8344
# Epoch 31/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9595 - acc: 0.9941 - val_loss: 1.5537 - val_acc: 0.8647
# Epoch 32/200
# 488/488 [==============================] - 14s 28ms/step - loss: 0.9619 - acc: 0.9927 - val_loss: 1.4407 - val_acc: 0.8801
# Epoch 33/200
# 488/488 [==============================] - 14s 28ms/step - loss: 0.9669 - acc: 0.9905 - val_loss: 1.4211 - val_acc: 0.8826
# Epoch 34/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9493 - acc: 0.9967 - val_loss: 1.3879 - val_acc: 0.8929
# Epoch 35/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9544 - acc: 0.9951 - val_loss: 1.4864 - val_acc: 0.8657
# Epoch 36/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9498 - acc: 0.9972 - val_loss: 1.4268 - val_acc: 0.8888
# Epoch 37/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9592 - acc: 0.9938 - val_loss: 1.3899 - val_acc: 0.8852
# Epoch 38/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9584 - acc: 0.9936 - val_loss: 1.3906 - val_acc: 0.8965
# Epoch 39/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9505 - acc: 0.9969 - val_loss: 1.3713 - val_acc: 0.8995
# Epoch 40/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9506 - acc: 0.9967 - val_loss: 1.4287 - val_acc: 0.8857
# Epoch 41/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9457 - acc: 0.9982 - val_loss: 1.4509 - val_acc: 0.8893
# Epoch 42/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9476 - acc: 0.9974 - val_loss: 1.5951 - val_acc: 0.8662
# Epoch 43/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9497 - acc: 0.9974 - val_loss: 1.4349 - val_acc: 0.8944
# Epoch 44/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9552 - acc: 0.9953 - val_loss: 1.8199 - val_acc: 0.8416
# Epoch 45/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9594 - acc: 0.9932 - val_loss: 1.4323 - val_acc: 0.8949
# Epoch 46/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9513 - acc: 0.9960 - val_loss: 1.5112 - val_acc: 0.8734
# Epoch 47/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9594 - acc: 0.9941 - val_loss: 1.6419 - val_acc: 0.8560
# Epoch 48/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9553 - acc: 0.9953 - val_loss: 1.6172 - val_acc: 0.8647
# Epoch 49/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9577 - acc: 0.9941 - val_loss: 1.4557 - val_acc: 0.8949
# Epoch 50/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9484 - acc: 0.9969 - val_loss: 1.4462 - val_acc: 0.8780
# Epoch 51/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9544 - acc: 0.9963 - val_loss: 1.4732 - val_acc: 0.8888
# Epoch 52/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9504 - acc: 0.9969 - val_loss: 1.4385 - val_acc: 0.8847
# Epoch 53/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9505 - acc: 0.9969 - val_loss: 1.4080 - val_acc: 0.9016
# Epoch 54/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9535 - acc: 0.9956 - val_loss: 1.6076 - val_acc: 0.8534
# Epoch 55/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9517 - acc: 0.9960 - val_loss: 1.6166 - val_acc: 0.8688
# Epoch 56/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9466 - acc: 0.9979 - val_loss: 1.4454 - val_acc: 0.8795
# Epoch 57/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9473 - acc: 0.9978 - val_loss: 1.5149 - val_acc: 0.8888
# Epoch 58/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9449 - acc: 0.9986 - val_loss: 1.4528 - val_acc: 0.8970
# Epoch 59/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9490 - acc: 0.9973 - val_loss: 1.4628 - val_acc: 0.8934
# Epoch 60/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9447 - acc: 0.9987 - val_loss: 1.4216 - val_acc: 0.9021
# Epoch 61/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9513 - acc: 0.9959 - val_loss: 1.7802 - val_acc: 0.8534
# Epoch 62/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9474 - acc: 0.9978 - val_loss: 1.4865 - val_acc: 0.8913
# Epoch 63/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9512 - acc: 0.9963 - val_loss: 1.3889 - val_acc: 0.9031
# Epoch 64/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9497 - acc: 0.9967 - val_loss: 1.5466 - val_acc: 0.8729
# Epoch 65/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9426 - acc: 0.9995 - val_loss: 1.3867 - val_acc: 0.8995
# Epoch 66/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9457 - acc: 0.9979 - val_loss: 1.4191 - val_acc: 0.9001
# Epoch 67/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9452 - acc: 0.9978 - val_loss: 1.4109 - val_acc: 0.9006
# Epoch 68/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9472 - acc: 0.9979 - val_loss: 1.6490 - val_acc: 0.8739
# Epoch 69/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9447 - acc: 0.9983 - val_loss: 1.4413 - val_acc: 0.8970
# Epoch 70/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9441 - acc: 0.9988 - val_loss: 1.5177 - val_acc: 0.8872
# Epoch 71/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9511 - acc: 0.9958 - val_loss: 1.6101 - val_acc: 0.8657
# Epoch 72/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9480 - acc: 0.9974 - val_loss: 1.7214 - val_acc: 0.8642
# Epoch 73/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9470 - acc: 0.9982 - val_loss: 1.4525 - val_acc: 0.8939
# Epoch 74/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9479 - acc: 0.9972 - val_loss: 1.6223 - val_acc: 0.8862
# Epoch 75/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9487 - acc: 0.9974 - val_loss: 1.6055 - val_acc: 0.8811
# Epoch 76/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9486 - acc: 0.9974 - val_loss: 1.4514 - val_acc: 0.9011
# Epoch 77/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9445 - acc: 0.9988 - val_loss: 1.4329 - val_acc: 0.8975
# Epoch 78/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9466 - acc: 0.9982 - val_loss: 1.5960 - val_acc: 0.8693
# Epoch 79/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9481 - acc: 0.9971 - val_loss: 1.4222 - val_acc: 0.9052
# Epoch 80/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9477 - acc: 0.9976 - val_loss: 1.4985 - val_acc: 0.8919
# Epoch 81/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9506 - acc: 0.9958 - val_loss: 1.5896 - val_acc: 0.8693
# Epoch 82/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9518 - acc: 0.9967 - val_loss: 1.7228 - val_acc: 0.8570
# Epoch 83/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9517 - acc: 0.9976 - val_loss: 1.4702 - val_acc: 0.8888
# Epoch 84/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9429 - acc: 0.9992 - val_loss: 1.5196 - val_acc: 0.8908
# Epoch 85/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9444 - acc: 0.9990 - val_loss: 1.4254 - val_acc: 0.9036
# Epoch 86/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9421 - acc: 0.9994 - val_loss: 1.4340 - val_acc: 0.9016
# Epoch 87/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9422 - acc: 0.9995 - val_loss: 1.4327 - val_acc: 0.9072
# Epoch 88/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9435 - acc: 0.9992 - val_loss: 1.4890 - val_acc: 0.9021
# Epoch 89/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9475 - acc: 0.9974 - val_loss: 1.5819 - val_acc: 0.8647
# Epoch 90/200
# 488/488 [==============================] - 14s 28ms/step - loss: 0.9439 - acc: 0.9990 - val_loss: 1.4038 - val_acc: 0.9026
# Epoch 91/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9458 - acc: 0.9981 - val_loss: 1.6802 - val_acc: 0.8601
# Epoch 92/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9459 - acc: 0.9979 - val_loss: 1.6469 - val_acc: 0.8611
# Epoch 93/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9440 - acc: 0.9987 - val_loss: 1.4817 - val_acc: 0.8980
# Epoch 94/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9414 - acc: 0.9999 - val_loss: 1.4444 - val_acc: 0.9072
# Epoch 95/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9463 - acc: 0.9982 - val_loss: 1.4590 - val_acc: 0.8965
# Epoch 96/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9441 - acc: 0.9985 - val_loss: 1.4793 - val_acc: 0.8919
# Epoch 97/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9463 - acc: 0.9981 - val_loss: 1.4397 - val_acc: 0.8990
# Epoch 98/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9474 - acc: 0.9973 - val_loss: 1.4243 - val_acc: 0.9031
# Epoch 99/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9445 - acc: 0.9986 - val_loss: 1.5347 - val_acc: 0.8913
# Epoch 100/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9468 - acc: 0.9973 - val_loss: 1.4530 - val_acc: 0.8934
# Epoch 101/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9440 - acc: 0.9988 - val_loss: 1.4137 - val_acc: 0.9026
# Epoch 102/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9426 - acc: 0.9991 - val_loss: 1.9263 - val_acc: 0.8273
# Epoch 103/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9442 - acc: 0.9988 - val_loss: 1.5876 - val_acc: 0.8790
# Epoch 104/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9437 - acc: 0.9988 - val_loss: 1.5007 - val_acc: 0.9031
# Epoch 105/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9441 - acc: 0.9991 - val_loss: 1.4035 - val_acc: 0.9088
# Epoch 106/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9442 - acc: 0.9983 - val_loss: 1.5021 - val_acc: 0.9006
# Epoch 107/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9426 - acc: 0.9996 - val_loss: 1.4560 - val_acc: 0.8944
# Epoch 108/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9425 - acc: 0.9992 - val_loss: 1.4176 - val_acc: 0.9088
# Epoch 109/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9425 - acc: 0.9992 - val_loss: 1.4346 - val_acc: 0.9026
# Epoch 110/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9432 - acc: 0.9990 - val_loss: 1.4027 - val_acc: 0.9042
# Epoch 111/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9447 - acc: 0.9986 - val_loss: 1.4581 - val_acc: 0.9031
# Epoch 112/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9423 - acc: 0.9994 - val_loss: 1.5290 - val_acc: 0.8867
# Epoch 113/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9447 - acc: 0.9983 - val_loss: 1.4372 - val_acc: 0.9001
# Epoch 114/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9415 - acc: 0.9995 - val_loss: 1.4411 - val_acc: 0.9026
# Epoch 115/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9418 - acc: 0.9996 - val_loss: 1.6612 - val_acc: 0.8765
# Epoch 116/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9474 - acc: 0.9978 - val_loss: 1.5664 - val_acc: 0.8867
# Epoch 117/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9515 - acc: 0.9964 - val_loss: 1.4853 - val_acc: 0.8960
# Epoch 118/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9467 - acc: 0.9981 - val_loss: 1.4508 - val_acc: 0.8960
# Epoch 119/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9441 - acc: 0.9982 - val_loss: 1.5306 - val_acc: 0.8960
# Epoch 120/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9466 - acc: 0.9982 - val_loss: 1.5027 - val_acc: 0.8877
# Epoch 121/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9422 - acc: 0.9992 - val_loss: 1.5316 - val_acc: 0.8867
# Epoch 122/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9452 - acc: 0.9985 - val_loss: 1.4259 - val_acc: 0.9031
# Epoch 123/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9458 - acc: 0.9983 - val_loss: 1.4324 - val_acc: 0.8985
# Epoch 124/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9504 - acc: 0.9973 - val_loss: 1.4324 - val_acc: 0.9011
# Epoch 125/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9408 - acc: 1.0000 - val_loss: 1.3821 - val_acc: 0.9067
# Epoch 126/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9428 - acc: 0.9990 - val_loss: 1.5959 - val_acc: 0.8867
# Epoch 127/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9430 - acc: 0.9990 - val_loss: 1.3797 - val_acc: 0.9149
# Epoch 128/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9441 - acc: 0.9986 - val_loss: 1.5000 - val_acc: 0.8954
# Epoch 129/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9412 - acc: 0.9997 - val_loss: 1.3889 - val_acc: 0.9072
# Epoch 130/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9427 - acc: 0.9994 - val_loss: 1.3924 - val_acc: 0.9062
# Epoch 131/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9407 - acc: 0.9999 - val_loss: 1.3988 - val_acc: 0.9062
# Epoch 132/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9408 - acc: 0.9997 - val_loss: 1.4214 - val_acc: 0.9062
# Epoch 133/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9407 - acc: 1.0000 - val_loss: 1.4064 - val_acc: 0.9083
# Epoch 134/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9409 - acc: 0.9997 - val_loss: 1.4311 - val_acc: 0.9057
# Epoch 135/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9406 - acc: 1.0000 - val_loss: 1.3899 - val_acc: 0.9103
# Epoch 136/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9416 - acc: 0.9994 - val_loss: 1.4647 - val_acc: 0.8985
# Epoch 137/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9434 - acc: 0.9990 - val_loss: 1.4848 - val_acc: 0.8980
# Epoch 138/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9434 - acc: 0.9990 - val_loss: 1.5018 - val_acc: 0.8919
# Epoch 139/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9432 - acc: 0.9988 - val_loss: 1.4570 - val_acc: 0.9067
# Epoch 140/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9422 - acc: 0.9995 - val_loss: 1.3892 - val_acc: 0.9042
# Epoch 141/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9420 - acc: 0.9995 - val_loss: 1.4120 - val_acc: 0.9067
# Epoch 142/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9420 - acc: 0.9996 - val_loss: 1.3935 - val_acc: 0.9057
# Epoch 143/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9428 - acc: 0.9988 - val_loss: 1.4205 - val_acc: 0.9042
# Epoch 144/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9430 - acc: 0.9987 - val_loss: 1.4133 - val_acc: 0.9047
# Epoch 145/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9423 - acc: 0.9992 - val_loss: 1.4850 - val_acc: 0.9016
# Epoch 146/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9450 - acc: 0.9985 - val_loss: 1.4541 - val_acc: 0.9093
# Epoch 147/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9442 - acc: 0.9988 - val_loss: 1.4937 - val_acc: 0.8990
# Epoch 148/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9451 - acc: 0.9983 - val_loss: 1.5635 - val_acc: 0.8877
# Epoch 149/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9457 - acc: 0.9986 - val_loss: 1.5453 - val_acc: 0.8919
# Epoch 150/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9424 - acc: 0.9995 - val_loss: 1.4305 - val_acc: 0.9026
# Epoch 151/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9419 - acc: 0.9995 - val_loss: 2.1752 - val_acc: 0.8139
# Epoch 152/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9428 - acc: 0.9988 - val_loss: 1.4603 - val_acc: 0.8990
# Epoch 153/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9441 - acc: 0.9985 - val_loss: 1.4822 - val_acc: 0.9062
# Epoch 154/200
# 488/488 [==============================] - 13s 26ms/step - loss: 0.9475 - acc: 0.9978 - val_loss: 1.5166 - val_acc: 0.8852
# Epoch 155/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9470 - acc: 0.9971 - val_loss: 1.4801 - val_acc: 0.8949
# Epoch 156/200
# 488/488 [==============================] - 13s 27ms/step - loss: 0.9438 - acc: 0.9987 - val_loss: 1.4326 - val_acc: 0.8985
# Epoch 157/200
# 488/488 [==============================] - 13s 28ms/step - loss: 0.9415 - acc: 0.9995 - val_loss: 1.4355 - val_acc: 0.9036

# %%
loss, accuracy = model2.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# Predicting the Test set results
pred = model2.predict(X_test)
print("Y_pred:", pred)
print("*****************")
y_pred2 = np.argmax(pred, axis = 1)
y_true2 = np.argmax(y_test, axis = 1)
